# %% [markdown]
# <a href="https://colab.research.google.com/github/Shazoyasho07/GIAIC-Q3/blob/main/Q3Class_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Class* *01*  "*Q3*"  (**22**-**FEB**-**2025**)

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
full_name : int = "Shahzeen"
print(type(full_name))
# Out:
# <class 'str'>

# %%
float_number: float = 9.789
print(type(float_number))
# Out:
# <class 'float'>

# %%
is_teacher: bool = True
print(type(is_teacher))
# Out:
# <class 'bool'>

# %%
first_name: str = "Shahzeen"
last_name: str = "Yaseen"

full_name: str = first_name + " " + last_name

print(full_name)
# Out:
# Shahzeen Yaseen

# %%
first_name: str = "Shahzeen"
last_name: str = "Yaseen"

full_name: str = f"{first_name} {last_name}"

print(full_name)
# Out:
# Shahzeen Yaseen

# %%
achievement: str ="""Thrilled to share i'm passing Q2 exams!"""
print(achievement)
# Out:
# Thrilled to share i'm passing Q2 exams!

# %%
achievement: str ="Thrilled to share i'm passing Q2 exams!"
print(type(achievement))
# Out:
# <class 'str'>

# %%
quarter: str = "Q3"

# %%
achievement: str =f"""Thrilled to share i'm passing {quarter} exams!"""
print(quarter)
# Out:
# Q3

# %%
quarter: str = "Q3"

# %%
achievement: str =f"""Thrilled to share i'm passing {quarter} exams!"""
print(id(achievement))
# Out:
# 139471915318992

# %%
fruits = ["Orange","Strawberry","Banana"]
print(len(fruits))
# Out:
# 3

# %%
fruits = ["Orange","Strawberry","Banana"]
print(fruits)
# Out:
# ['Orange', 'Strawberry', 'Banana']

# %%
fruits = ["Orange","Strawberry","Banana"]
print(fruits[1])
# Out:
# Strawberry

# %%
fruits = ["Orange","Strawberry","Banana"]
print(fruits[0:2])
# Out:
# ['Orange', 'Strawberry']

# %%
a: int = 10
b: int = 20

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
# Out:
# 30
# -10
# 200
# 0.5
# 0
